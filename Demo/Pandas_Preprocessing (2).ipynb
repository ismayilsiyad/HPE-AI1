# %%
import pandas as pd

# %% [markdown]
# 1d - Series
# 2d  - Dataframe

# %%
sr = pd.Series([10,20,30,40,50])

# %%
sr
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr[2]
# Out:
# 30

# %% [markdown]
# # DataFrame

# %%
student_id = [1,2,3,4,5]
english = [32,50,41,48,21]
science = [25,45,50,21,32]
maths = [12,25,41,50,50]


df = pd.DataFrame({"Student_ID":student_id, "English":english, "Science":science, "Mathematics":maths})

# %%
df
# Out:
#    Student_ID  English  Science  Mathematics
# 0           1       32       25           12
# 1           2       50       45           25
# 2           3       41       50           41
# 3           4       48       21           50
# 4           5       21       32           50

# %%
type(df.English)
# Out:
# pandas.core.series.Series

# %% [markdown]
# CREATE
# READ
# UPDATE
# DELETE

# %%
df.Science
# Out:
# 0    25
# 1    45
# 2    50
# 3    21
# 4    32
# Name: Science, dtype: int64

# %%
df["English"]
# Out:
# 0    32
# 1    50
# 2    41
# 3    48
# 4    21
# Name: English, dtype: int64

# %%
df[["Student_ID","Mathematics","Mathematics"]]
# Out:
#    Student_ID  Mathematics  Mathematics
# 0           1           12           12
# 1           2           25           25
# 2           3           41           41
# 3           4           50           50
# 4           5           50           50

# %%
df.iloc[0]
# Out:
# Student_ID      1
# English        32
# Science        25
# Mathematics    12
# Name: 0, dtype: int64

# %%
df.iloc[0:3,0:3]
# Out:
#    Student_ID  English  Science
# 0           1       32       25
# 1           2       50       45
# 2           3       41       50

# %%
df.iloc[:,0:2]
# Out:
#    Student_ID  English
# 0           1       32
# 1           2       50
# 2           3       41
# 3           4       48
# 4           5       21

# %%
df.iloc[0:2,:]
# Out:
#    Student_ID  English  Science  Mathematics
# 0           1       32       25           12
# 1           2       50       45           25
# 2           3       41       50           41

# %%
df.loc[0:2,"English"] = [555,555,555]

# %%
df
# Out:
#    Student_ID  English  Science  Mathematics
# 0           1      555       25           12
# 1           2      555       45           25
# 2           3      555       50           41
# 3           4       48       21           50
# 4           5       21       32           50

# %%
condition = df["English"] > 500

df[condition]
# Out:
#    Student_ID  English  Science  Mathematics
# 0           1      555       25           12
# 1           2      555       45           25
# 2           3      555       50           41

# %%
tn = pd.read_csv("https://raw.githubusercontent.com/ismayilsiyad/HPE-AI1/main/Lab%202/titanic.csv")

# %%
tn
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tn.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
tn.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
tn.size
# Out:
# 10692

# %%
type(tn)
# Out:
# pandas.core.frame.DataFrame

# %%
tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tn.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
tn.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tn1 = tn.dropna()

# %%
tn1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %%
tn.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tn["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
tn["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
tn2 = tn.drop("Cabin", axis=1)
tn2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tn
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tn.drop("Cabin", axis=1, inplace=True)

# %%
tn
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tn["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
tn["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
tn["Embarked"].fillna("S", inplace=True)

# %%
tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
tn["Age"].fillna(tn["Age"].median, inplace=True )

# %%
tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 76.7+ KB

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.2.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author: None
# Author-email: None
# License: new BSD
# Location: /home/ubuntu/environments/hpepyspark/lib/python3.8/site-packages
# Requires: joblib, threadpoolctl, scipy, numpy
# Required-by: shapash, shap, lightgbm, handyspark, category-encoders, alibi-detect
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
tn["Sex"] = le.fit_transform(tn["Sex"])

# %%
tn.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
df["English"] = mms.fit_transform(df[["English"]])

# %%
df
# Out:
#    Student_ID   English  Science  Mathematics
# 0           1  1.000000       25           12
# 1           2  1.000000       45           25
# 2           3  1.000000       50           41
# 3           4  0.050562       21           50
# 4           5  0.000000       32           50

# %% [markdown]
# Data Visualization

# %% [markdown]
# Matplotlib
#
# Seaborn

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.7.1
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /home/ubuntu/environments/hpepyspark/lib/python3.8/site-packages
# Requires: importlib-resources, pyparsing, numpy, contourpy, kiwisolver, python-dateutil, pillow, cycler, packaging, fonttools
# Required-by: wordcloud, shapash, seaborn, handyspark, catboost, alibi-detect
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page: None
# Author: None
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License: None
# Location: /home/ubuntu/environments/hpepyspark/lib/python3.8/site-packages
# Requires: matplotlib, pandas, numpy
# Required-by: handyspark, eurybia
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
plt.plot(df["Student_ID"], df["Science"], color = 'red', label = "science")
plt.plot(df["Student_ID"], df["Mathematics"], color = 'black', label = "Maths")
plt.xlabel("Student ID")
plt.ylabel("Science Marks")
plt.title("Science MArk of Students")
plt.legend()
plt.savefig("abc.png")
plt.show()

# %%
plt.figure()
sns.distplot(tn["Fare"], bins=10)
plt.show()
# Out:
# /tmp/ipykernel_3751/4039910270.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tn["Fare"], bins=10)

# %%
plt.figure()
sns.boxplot(data=tn, y= "Fare")
plt.show()

# %%
b
